# %% [markdown]
# Write a simple program for a card Role-Playing Game. Try to use only the concepts you have learned so far in the lectures.
#
# REQUIREMENTS:
#
# 1. Following are the different cards, with their characteristics, available to the player
#
# Name: Diablo
# Health: 100
# Attack: 90
# Defense: 60
#
# Name: Medusa
# Health: 100
# Attack: 70
# Defense: 70
#
# Name: Jester
# Health: 120
# Attack: 60
# Defense: 90
#
# Name: Troll
# Health: 150
# Attack: 40
# Defense: 94
#
# Name: Specter
# Health: 100
# Attack: 70
# Defense: 70
#
# Name: Mist
# Health: 100
# Attack: 75
# Defense: 65
#
# Name: Savage
# Health: 100
# Attack: 90
# Defense: 50
#
# Name: Marauder
# Health: 100
# Attack: 85
# Defense: 50
#
# Name: Wimp
# Health: 110
# Attack: 40
# Defense: 85
#
# Name: Sorcerer
# Health: 100
# Attack: 70
# Defense: 55
#
# 2. Store the above card details using a suitable data structure like list, tuple, dictionary, or any combination of these
# 3. From these cards, assign a random deck of 5 cards to both the player and the computer (opponent).
#     3.1. This should happen whenever a new game begins
# 4. Keep the game running for as long as there are cards in the player's deck or for as long as there are cards in the opponent's deck
#     4.1. Show all the cards that the player has in their deck
#     4.2. Assign a random card to the opponent, and show that to the player, along with the details of that card. Only the details of this random card must be shown.
#     4.3. Ask the player to pick a card from their own deck to fight the opponent's card.
#     4.4. If the attack value of the player's card is more than the health of opponent's card, then the player wins this round.
#     4.5. Otherwise, the player's card will fight with the opponent's card.
#         4.5.1. Calculate the damage the player's card does to the opponent's card. This calculation should take care of the fact that the opponent's card will first defend the attack using its 'Defense' value. And if there is no defense value, only then will the player's attack value will affect the opponent card's health.
#
#         e.g.,
#         Player card
#
#         Name: Wimp
#         Health: 110
#         Attack: 40
#         Defense: 85
#
#
#         Opponent card
#
#         Name: Sorcerer
#         Health: 100
#         Attack: 70
#         Defense: 55
#
#         If the Wimp attacks Sorcerer, first, it will only affect Sorcerer's 'Defense' value. Sorcerer's defense value will decrease by the the attack value of player's Wimp card. Therefore, after the attack, the defense value will change from 55 to 15, as 55 - 40 = 15. Therefore,
#
#         Opponent card
#
#         Name: Sorcerer
#         Health: 100
#         Attack: 70
#         Defense: 15
#
#         Now, if in the next round, Wimp attacks Sorcerer again, then Sorcerer's defense value will decrease to 0, but its health will also be affected. The health will be affected by 25 points, as 40 - 15 = 25. So, Sorcerer's health will now decrease from 100 to 75
#
#         Opponent card
#
#         Name: Sorcerer
#         Health: 75
#         Attack: 70
#         Defense: 0
#
#         Now, let's say in a later round, the player uses the Marauder card, which has an attack value of 85, and the computer is using Sorcerer, whose health value is 75.
#
#         In that case, Sorcerer will be defeated, as 85 > 75. When this happens, remove the Sorcerer card from the deck of the opponent.
#
#         Display properly all these changes to the player at every round, so that they know how their attacks affected the round and what they can do next.
#
#         DO NOT just show the card details. Write proper statements, describing the process, as you may have seen in the demonstration given by the teacher
#
#         4.5.2. After the user's turn, make sure all the card values adjusted accordingly, just as described above.
#         4.5.3. ONLY a card's 'Defense' and 'Health' value changes after an attack. And once the 'Health' value of a card reaches 0 or drops below it, that card MUST be removed from the deck.
#         4.5.4. After the player's turn, pause the second for some seconds, e.g., time.sleep(3) will pause the game for 3 seconds.
#     4.6. Display that now it's the opponent's turn.
#     4.7. Make sure there are cards available in opponent's deck. If there aren't, then the game ends and the player wins.
#     4.8. If there are still cards available in opponent's deck, draw a random card from the opponent's deck, and display its details to the player.
#     4.9. Then display the cards available in the player's deck.
#     4.10 Ask the user to pick one card from their own deck to fight the opponent's card.
#     4.11. REPEAT THE SAME LOGIC AS STATED FROM POINT 4.4 TO 4.5.3. But this time, from the perspective of the opponent.
#     4.12. After the opponent's turn is over, display that a new round will begin in some seconds.
# 5. If it's found that the opponent has no card in their deck, then display a message stating player is the winner, otherwise display that the opponent won.

# %%
import random
import time
import copy

card_deck = [
    {"Name": "Diablo", "Health": 100, "Attack": 90, "Defense": 60},
    {"Name": "Medusa", "Health": 100, "Attack": 70, "Defense": 70},
    {"Name": "Jester", "Health": 120, "Attack": 60, "Defense": 90},
    {"Name": "Troll", "Health": 150, "Attack": 40, "Defense": 94},
    {"Name": "Specter", "Health": 100, "Attack": 70, "Defense": 70},
    {"Name": "Mist", "Health": 100, "Attack": 75, "Defense": 65},
    {"Name": "Savage", "Health": 100, "Attack": 90, "Defense": 50},
    {"Name": "Marauder", "Health": 100, "Attack": 85, "Defense": 50},
    {"Name": "Wimp", "Health": 110, "Attack": 40, "Defense": 85},
    {"Name": "Sorcerer", "Health": 100, "Attack": 70, "Defense": 55}
]

deck_size = 5

def display_card(card):
    print(f"Name: {card['Name']}")
    print(f"  Health: {card['Health']}")
    print(f"  Attack: {card['Attack']}")
    print(f"  Defense: {card['Defense']}")

def display_deck(deck, owner="Player"):
    print(f"\n{owner}'s Deck:")
    for idx, card in enumerate(deck, 1):
        print(f"{idx}. {card['Name']} (Health: {card['Health']}, Attack: {card['Attack']}, Defense: {card['Defense']})")

def choose_player_card(deck):
    while True:
        try:
            choice = int(input("\nChoose a card to attack with (Enter the number): "))
            if 1 <= choice <= len(deck):
                return deck[choice - 1]
            else:
                print(f"Please enter a number between 1 and {len(deck)}.")
        except ValueError:
            print("Invalid input. Please enter a number.")

def handle_attack(attacker, defender, attacker_owner, defender_owner):
    print(f"\n{attacker_owner}'s '{attacker['Name']}' attacks {defender_owner}'s '{defender['Name']}'!")

    if attacker['Attack'] > defender['Health']:
        print(f"Attack value ({attacker['Attack']}) is greater than {defender_owner}'s '{defender['Name']}' Health ({defender['Health']}).")
        print(f"{defender_owner}'s '{defender['Name']}' is defeated!")
        return 'defeated'
    else:
        print(f"Attack value ({attacker['Attack']}) is not enough to defeat {defender_owner}'s '{defender['Name']}' outright.")
        original_defense = defender['Defense']
        defender['Defense'] -= attacker['Attack']
        if defender['Defense'] > 0:
            print(f"{defender_owner}'s '{defender['Name']}' Defense reduced from {original_defense} to {defender['Defense']}.")
        else:
            damage = abs(defender['Defense'])
            defender['Defense'] = 0
            defender['Health'] -= damage
            print(f"{defender_owner}'s '{defender['Name']}' Defense reduced to 0.")
            print(f"{defender_owner}'s '{defender['Name']}' Health reduced by {damage} to {defender['Health']}.")

            if defender['Health'] <= 0:
                print(f"{defender_owner}'s '{defender['Name']}' is defeated!")
                return 'defeated'
        return 'ongoing'

def start_game():
    print("Welcome to the Card Role-Playing Game!\n")

    player_deck = copy.deepcopy(random.sample(card_deck, deck_size))
    opponent_deck = copy.deepcopy(random.sample(card_deck, deck_size))

    round_number = 1

    while player_deck and opponent_deck:
        print(f"\n--- Round {round_number} ---")

        print("\nYour Turn:")
        display_deck(player_deck, "Your")
        opponent_card = random.choice(opponent_deck)
        print("\nOpponent has played the following card:")
        display_card(opponent_card)
        player_card = choose_player_card(player_deck)
        result = handle_attack(player_card, opponent_card, "Player", "Opponent")
        if result == 'defeated':
            opponent_deck.remove(opponent_card)
        time.sleep(3)
        if not opponent_deck:
            print("\nOpponent has no more cards left. You win the game!")
            break

        print("\nOpponent's Turn:")
        opponent_attack_card = random.choice(opponent_deck)
        print("\nOpponent has played the following card:")
        display_card(opponent_attack_card)
        display_deck(player_deck, "Your")
        player_defense_card = choose_player_card(player_deck)
        result = handle_attack(opponent_attack_card, player_defense_card, "Opponent", "Player")

        if result == 'defeated':
            player_deck.remove(player_defense_card)

        time.sleep(3)
        if not player_deck:
            print("\nYou have no more cards left. Opponent wins the game!")
            break

        print("\nA new round will begin in 3 seconds...")
        time.sleep(3)
        round_number += 1

    if player_deck and not opponent_deck:
        print("\nCongratulations! You have defeated all opponent's cards and won the game!")
    elif opponent_deck and not player_deck:
        print("\nAll your cards have been defeated. The opponent wins the game!")
    else:
        print("\nThe game has ended.")

if __name__ == "__main__":
    start_game()
# Out:
# Welcome to the Card Role-Playing Game!
#
#
# --- Round 1 ---
#
# Your Turn:
#
# Your's Deck:
# 1. Diablo (Health: 100, Attack: 90, Defense: 60)
# 2. Savage (Health: 100, Attack: 90, Defense: 50)
# 3. Marauder (Health: 100, Attack: 85, Defense: 50)
# 4. Specter (Health: 100, Attack: 70, Defense: 70)
# 5. Troll (Health: 150, Attack: 40, Defense: 94)
#
# Opponent has played the following card:
# Name: Mist
#   Health: 100
#   Attack: 75
#   Defense: 65
#
# Player's 'Savage' attacks Opponent's 'Mist'!
# Attack value (90) is not enough to defeat Opponent's 'Mist' outright.
# Opponent's 'Mist' Defense reduced to 0.
# Opponent's 'Mist' Health reduced by 25 to 75.
#
# Opponent's Turn:
#
# Opponent has played the following card:
# Name: Jester
#   Health: 120
#   Attack: 60
#   Defense: 90
#
# Your's Deck:
# 1. Diablo (Health: 100, Attack: 90, Defense: 60)
# 2. Savage (Health: 100, Attack: 90, Defense: 50)
# 3. Marauder (Health: 100, Attack: 85, Defense: 50)
# 4. Specter (Health: 100, Attack: 70, Defense: 70)
# 5. Troll (Health: 150, Attack: 40, Defense: 94)
#
# Opponent's 'Jester' attacks Player's 'Marauder'!
# Attack value (60) is not enough to defeat Player's 'Marauder' outright.
# Player's 'Marauder' Defense reduced to 0.
# Player's 'Marauder' Health reduced by 10 to 90.
#
# A new round will begin in 3 seconds...
#
# --- Round 2 ---
#
# Your Turn:
#
# Your's Deck:
# 1. Diablo (Health: 100, Attack: 90, Defense: 60)
# 2. Savage (Health: 100, Attack: 90, Defense: 50)
# 3. Marauder (Health: 90, Attack: 85, Defense: 0)
# 4. Specter (Health: 100, Attack: 70, Defense: 70)
# 5. Troll (Health: 150, Attack: 40, Defense: 94)
#
# Opponent has played the following card:
# Name: Wimp
#   Health: 110
#   Attack: 40
#   Defense: 85
#
# Player's 'Savage' attacks Opponent's 'Wimp'!
# Attack value (90) is not enough to defeat Opponent's 'Wimp' outright.
# Opponent's 'Wimp' Defense reduced to 0.
# Opponent's 'Wimp' Health reduced by 5 to 105.
#
# Opponent's Turn:
#
# Opponent has played the following card:
# Name: Sorcerer
#   Health: 100
#   Attack: 70
#   Defense: 55
#
# Your's Deck:
# 1. Diablo (Health: 100, Attack: 90, Defense: 60)
# 2. Savage (Health: 100, Attack: 90, Defense: 50)
# 3. Marauder (Health: 90, Attack: 85, Defense: 0)
# 4. Specter (Health: 100, Attack: 70, Defense: 70)
# 5. Troll (Health: 150, Attack: 40, Defense: 94)
#
# Opponent's 'Sorcerer' attacks Player's 'Marauder'!
# Attack value (70) is not enough to defeat Player's 'Marauder' outright.
# Player's 'Marauder' Defense reduced to 0.
# Player's 'Marauder' Health reduced by 70 to 20.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 120
#     117         print("\nThe game has ended.")
#     119 if __name__ == "__main__":
# --> 120     start_game()
#
# Cell In[1], line 103, in start_game()
#     100 if result == 'defeated':
#     101     player_deck.remove(player_defense_card)
# --> 103 time.sleep(3)
#     104 if not player_deck:
#     105     print("\nYou have no more cards left. Opponent wins the game!")
#
# KeyboardInterrupt:
